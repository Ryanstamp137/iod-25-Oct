# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd 
import warnings
from datetime import datetime as dt

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
warnings.filterwarnings("ignore")
sns.set_style("dark")
plt.rcParams['figure.dpi']=100

# %%
#Data Loading

# %%
product_info = pd.read_csv('../DATA/product_info.csv')
customer_product = pd.read_csv('../DATA/customer_product.csv', index_col = 0)
customer_info = pd.read_csv('../DATA/customer_info.csv', index_col = 0)
customer_cases = pd.read_csv('../DATA/customer_cases.csv', index_col = 0)

# %%
#Data Preparation and Cleaning

# %%
product_info.head()
# Out:
#   product_id                  name  price  billing_cycle
# 0      prd_1   annual_subscription   1200             12
# 1      prd_2  monthly_subscription    125              1

# %%
print(product_info.isnull().sum())
# Out:
# product_id       0
# name             0
# price            0
# billing_cycle    0
# dtype: int64

# %%
customer_product.head()
# Out:
#   customer_id product     signup_date_time     cancel_date_time
# 1       C2448   prd_1  2017-01-01 10:35:09                  NaN
# 2       C2449   prd_1  2017-01-01 11:39:29  2021-09-05 10:00:02
# 3       C2450   prd_1  2017-01-01 11:42:00  2019-01-13 16:24:55
# 4       C2451   prd_2  2017-01-01 13:32:08                  NaN
# 5       C2452   prd_1  2017-01-01 13:57:30  2021-06-28 18:06:01

# %%
customer_product.rename(columns = {'product':'product_id'}, inplace = True)

# %%
customer_product.head()
# Out:
#   customer_id product_id     signup_date_time     cancel_date_time
# 1       C2448      prd_1  2017-01-01 10:35:09                  NaN
# 2       C2449      prd_1  2017-01-01 11:39:29  2021-09-05 10:00:02
# 3       C2450      prd_1  2017-01-01 11:42:00  2019-01-13 16:24:55
# 4       C2451      prd_2  2017-01-01 13:32:08                  NaN
# 5       C2452      prd_1  2017-01-01 13:57:30  2021-06-28 18:06:01

# %%
churn = list()
for customer in customer_product["cancel_date_time"]:
    if type(customer)==float:
        churn.append(0)
    else:
        churn.append(1)
customer_product["chur"]=churn
customer_product.head()
# Out:
#   customer_id product_id     signup_date_time     cancel_date_time  chur
# 1       C2448      prd_1  2017-01-01 10:35:09                  NaN     0
# 2       C2449      prd_1  2017-01-01 11:39:29  2021-09-05 10:00:02     1
# 3       C2450      prd_1  2017-01-01 11:42:00  2019-01-13 16:24:55     1
# 4       C2451      prd_2  2017-01-01 13:32:08                  NaN     0
# 5       C2452      prd_1  2017-01-01 13:57:30  2021-06-28 18:06:01     1

# %%
customer_product['signup_date'] = customer_product['signup_date_time'].astype('datetime64').dt.date.astype('datetime64')
customer_product['cancel_date'] = customer_product['cancel_date_time'].astype('datetime64').dt.date.astype('datetime64')
customer_product['cancel_date'].fillna(dt(2022,1,1), inplace=True)

customer_product['signup_year'] = customer_product['signup_date'].dt.year.astype('int64')
customer_product['signup_month'] = customer_product['signup_date'].dt.month.astype('int64')
customer_product['cancel_year'] = customer_product['cancel_date'].dt.year.astype('int64')
customer_product['cancel_month'] = customer_product['cancel_date'].dt.month.astype('int64')

customer_product['duration'] = (customer_product['cancel_date'] - customer_product['signup_date']).dt.days.astype('int64')

# %%
customer_product
# Out:
#        customer_id product_id     signup_date_time     cancel_date_time  chur  \
# 1            C2448      prd_1  2017-01-01 10:35:09                  NaN     0
# 2            C2449      prd_1  2017-01-01 11:39:29  2021-09-05 10:00:02     1
# 3            C2450      prd_1  2017-01-01 11:42:00  2019-01-13 16:24:55     1
# 4            C2451      prd_2  2017-01-01 13:32:08                  NaN     0
# 5            C2452      prd_1  2017-01-01 13:57:30  2021-06-28 18:06:01     1
# ...            ...        ...                  ...                  ...   ...
# 508928     C511375      prd_2  2021-12-31 18:37:58                  NaN     0
# 508929     C511376      prd_2  2021-12-31 18:42:00                  NaN     0
# 508930     C511377      prd_2  2021-12-31 18:50:53                  NaN     0
# 508931     C511378      prd_2  2021-12-31 19:00:38                  NaN     0
# 508932     C511379      prd_2  2021-12-31 19:38:21                  NaN     0
#
#        signup_date cancel_date  signup_year  signup_month  cancel_year  \
# 1       2017-01-01  2022-01-01         2017             1         2022
# 2       2017-01-01  2021-09-05         2017             1         2021
# 3       2017-01-01  2019-01-13         2017             1         2019
# 4       2017-01-01  2022-01-01         2017             1         2022
# 5       2017-01-01  2021-06-28         2017             1         2021
# ...            ...         ...          ...           ...          ...
# 508928  2021-12-31  2022-01-01         2021            12         2022
# 508929  2021-12-31  2022-01-01         2021            12         2022
# 508930  2021-12-31  2022-01-01         2021            12         2022
# 508931  2021-12-31  2022-01-01         2021            12         2022
# 508932  2021-12-31  2022-01-01         2021            12         2022
#
#         cancel_month  duration
# 1                  1      1826
# 2                  9      1708
# 3                  1       742
# 4                  1      1826
# 5                  6      1639
# ...              ...       ...
# 508928             1         1
# 508929             1         1
# 508930             1         1
# 508931             1         1
# 508932             1         1
#
# [508932 rows x 12 columns]

# %%
customer_product['product_id'].value_counts()
# Out:
# prd_1    325649
# prd_2    183283
# Name: product_id, dtype: int64

# %%
customer_product['chur'].value_counts()
# Out:
# 0    396447
# 1    112485
# Name: chur, dtype: int64

# %%
list1 = ["product_id"]
customer_product_info = customer_product.merge(product_info,
                   on = list1, 
                   how = 'outer')
customer_product_info
# Out:
#        customer_id product_id     signup_date_time     cancel_date_time  chur  \
# 0            C2448      prd_1  2017-01-01 10:35:09                  NaN     0
# 1            C2449      prd_1  2017-01-01 11:39:29  2021-09-05 10:00:02     1
# 2            C2450      prd_1  2017-01-01 11:42:00  2019-01-13 16:24:55     1
# 3            C2452      prd_1  2017-01-01 13:57:30  2021-06-28 18:06:01     1
# 4            C2453      prd_1  2017-01-01 15:26:14                  NaN     0
# ...            ...        ...                  ...                  ...   ...
# 508927     C511375      prd_2  2021-12-31 18:37:58                  NaN     0
# 508928     C511376      prd_2  2021-12-31 18:42:00                  NaN     0
# 508929     C511377      prd_2  2021-12-31 18:50:53                  NaN     0
# 508930     C511378      prd_2  2021-12-31 19:00:38                  NaN     0
# 508931     C511379      prd_2  2021-12-31 19:38:21                  NaN     0
#
#        signup_date cancel_date  signup_year  signup_month  cancel_year  \
# 0       2017-01-01  2022-01-01         2017             1         2022
# 1       2017-01-01  2021-09-05         2017             1         2021
# 2       2017-01-01  2019-01-13         2017             1         2019
# 3       2017-01-01  2021-06-28         2017             1         2021
# 4       2017-01-01  2022-01-01         2017             1         2022
# ...            ...         ...          ...           ...          ...
# 508927  2021-12-31  2022-01-01         2021            12         2022
# 508928  2021-12-31  2022-01-01         2021            12         2022
# 508929  2021-12-31  2022-01-01         2021            12         2022
# 508930  2021-12-31  2022-01-01         2021            12         2022
# 508931  2021-12-31  2022-01-01         2021            12         2022
#
#         cancel_month  duration                  name  price  billing_cycle
# 0                  1      1826   annual_subscription   1200             12
# 1                  9      1708   annual_subscription   1200             12
# 2                  1       742   annual_subscription   1200             12
# 3                  6      1639   annual_subscription   1200             12
# 4                  1      1826   annual_subscription   1200             12
# ...              ...       ...                   ...    ...            ...
# 508927             1         1  monthly_subscription    125              1
# 508928             1         1  monthly_subscription    125              1
# 508929             1         1  monthly_subscription    125              1
# 508930             1         1  monthly_subscription    125              1
# 508931             1         1  monthly_subscription    125              1
#
# [508932 rows x 15 columns]

# %%
print(customer_product.isnull().sum())
# Out:
# customer_id              0
# product_id               0
# signup_date_time         0
# cancel_date_time    396447
# chur                     0
# signup_date              0
# cancel_date              0
# signup_year              0
# signup_month             0
# cancel_year              0
# cancel_month             0
# duration                 0
# dtype: int64

# %%
customer_info.head()
# Out:
#   customer_id  age  gender
# 1       C2448   76  female
# 2       C2449   61    male
# 3       C2450   58  female
# 4       C2451   62  female
# 5       C2452   71    male

# %%
print(customer_info.isnull().sum())
# Out:
# customer_id    0
# age            0
# gender         0
# dtype: int64

# %%
customer_info['gender'].value_counts()
# Out:
# male      309930
# female    199002
# Name: gender, dtype: int64

# %%
customer_info.insert(2,"agerange",pd.cut(customer_info["age"], [18, 35, 50, 65,150], labels=["18-35", "35-50", "50-65","65+"]))

# %%
list2 = ["customer_id"]
customer_product2 = customer_product_info.merge(customer_info,
                   on = list2, 
                   how = 'outer')
customer_product2
# Out:
#        customer_id product_id     signup_date_time     cancel_date_time  chur  \
# 0            C2448      prd_1  2017-01-01 10:35:09                  NaN     0
# 1            C2449      prd_1  2017-01-01 11:39:29  2021-09-05 10:00:02     1
# 2            C2450      prd_1  2017-01-01 11:42:00  2019-01-13 16:24:55     1
# 3            C2452      prd_1  2017-01-01 13:57:30  2021-06-28 18:06:01     1
# 4            C2453      prd_1  2017-01-01 15:26:14                  NaN     0
# ...            ...        ...                  ...                  ...   ...
# 508927     C511375      prd_2  2021-12-31 18:37:58                  NaN     0
# 508928     C511376      prd_2  2021-12-31 18:42:00                  NaN     0
# 508929     C511377      prd_2  2021-12-31 18:50:53                  NaN     0
# 508930     C511378      prd_2  2021-12-31 19:00:38                  NaN     0
# 508931     C511379      prd_2  2021-12-31 19:38:21                  NaN     0
#
#        signup_date cancel_date  signup_year  signup_month  cancel_year  \
# 0       2017-01-01  2022-01-01         2017             1         2022
# 1       2017-01-01  2021-09-05         2017             1         2021
# 2       2017-01-01  2019-01-13         2017             1         2019
# 3       2017-01-01  2021-06-28         2017             1         2021
# 4       2017-01-01  2022-01-01         2017             1         2022
# ...            ...         ...          ...           ...          ...
# 508927  2021-12-31  2022-01-01         2021            12         2022
# 508928  2021-12-31  2022-01-01         2021            12         2022
# 508929  2021-12-31  2022-01-01         2021            12         2022
# 508930  2021-12-31  2022-01-01         2021            12         2022
# 508931  2021-12-31  2022-01-01         2021            12         2022
#
#         cancel_month  duration                  name  price  billing_cycle  \
# 0                  1      1826   annual_subscription   1200             12
# 1                  9      1708   annual_subscription   1200             12
# 2                  1       742   annual_subscription   1200             12
# 3                  6      1639   annual_subscription   1200             12
# 4                  1      1826   annual_subscription   1200             12
# ...              ...       ...                   ...    ...            ...
# 508927             1         1  monthly_subscription    125              1
# 508928             1         1  monthly_subscription    125              1
# 508929             1         1  monthly_subscription    125              1
# 508930             1         1  monthly_subscription    125              1
# 508931             1         1  monthly_subscription    125              1
#
#         age agerange  gender
# 0        76      65+  female
# 1        61    50-65    male
# 2        58    50-65  female
# 3        71      65+    male
# 4        56    50-65    male
# ...     ...      ...     ...
# 508927   53    50-65    male
# 508928   60    50-65    male
# 508929   67      65+  female
# 508930   49    35-50    male
# 508931   55    50-65    male
#
# [508932 rows x 18 columns]

# %%
customer_cases.head()
# Out:
#   case_id            date_time customer_id channel  reason
# 1   CC101  2017-01-01 10:32:03       C2448   phone  signup
# 2   CC102  2017-01-01 11:35:47       C2449   phone  signup
# 3   CC103  2017-01-01 11:37:09       C2450   phone  signup
# 4   CC104  2017-01-01 13:28:14       C2451   phone  signup
# 5   CC105  2017-01-01 13:52:22       C2452   phone  signup

# %%
print(customer_cases.isnull().sum())
# Out:
# case_id        0
# date_time      0
# customer_id    0
# channel        0
# reason         0
# dtype: int64

# %%
customer_cases['reason'].value_counts()
# Out:
# support    200985
# signup     129527
# Name: reason, dtype: int64

# %%
list3 = ["customer_id"]
customer_final = customer_product2.merge(customer_cases,
                   on = list3, 
                   how = 'outer')
customer_final
# Out:
#        customer_id product_id     signup_date_time     cancel_date_time  chur  \
# 0            C2448      prd_1  2017-01-01 10:35:09                  NaN     0
# 1            C2449      prd_1  2017-01-01 11:39:29  2021-09-05 10:00:02     1
# 2            C2450      prd_1  2017-01-01 11:42:00  2019-01-13 16:24:55     1
# 3            C2452      prd_1  2017-01-01 13:57:30  2021-06-28 18:06:01     1
# 4            C2453      prd_1  2017-01-01 15:26:14                  NaN     0
# ...            ...        ...                  ...                  ...   ...
# 580779     C511375      prd_2  2021-12-31 18:37:58                  NaN     0
# 580780     C511376      prd_2  2021-12-31 18:42:00                  NaN     0
# 580781     C511377      prd_2  2021-12-31 18:50:53                  NaN     0
# 580782     C511378      prd_2  2021-12-31 19:00:38                  NaN     0
# 580783     C511379      prd_2  2021-12-31 19:38:21                  NaN     0
#
#        signup_date cancel_date  signup_year  signup_month  cancel_year  ...  \
# 0       2017-01-01  2022-01-01         2017             1         2022  ...
# 1       2017-01-01  2021-09-05         2017             1         2021  ...
# 2       2017-01-01  2019-01-13         2017             1         2019  ...
# 3       2017-01-01  2021-06-28         2017             1         2021  ...
# 4       2017-01-01  2022-01-01         2017             1         2022  ...
# ...            ...         ...          ...           ...          ...  ...
# 580779  2021-12-31  2022-01-01         2021            12         2022  ...
# 580780  2021-12-31  2022-01-01         2021            12         2022  ...
# 580781  2021-12-31  2022-01-01         2021            12         2022  ...
# 580782  2021-12-31  2022-01-01         2021            12         2022  ...
# 580783  2021-12-31  2022-01-01         2021            12         2022  ...
#
#                         name  price billing_cycle  age  agerange  gender  \
# 0        annual_subscription   1200            12   76       65+  female
# 1        annual_subscription   1200            12   61     50-65    male
# 2        annual_subscription   1200            12   58     50-65  female
# 3        annual_subscription   1200            12   71       65+    male
# 4        annual_subscription   1200            12   56     50-65    male
# ...                      ...    ...           ...  ...       ...     ...
# 580779  monthly_subscription    125             1   53     50-65    male
# 580780  monthly_subscription    125             1   60     50-65    male
# 580781  monthly_subscription    125             1   67       65+  female
# 580782  monthly_subscription    125             1   49     35-50    male
# 580783  monthly_subscription    125             1   55     50-65    male
#
#        case_id            date_time channel  reason
# 0        CC101  2017-01-01 10:32:03   phone  signup
# 1        CC102  2017-01-01 11:35:47   phone  signup
# 2        CC103  2017-01-01 11:37:09   phone  signup
# 3        CC105  2017-01-01 13:52:22   phone  signup
# 4        CC106  2017-01-01 15:23:02   phone  signup
# ...        ...                  ...     ...     ...
# 580779     NaN                  NaN     NaN     NaN
# 580780     NaN                  NaN     NaN     NaN
# 580781     NaN                  NaN     NaN     NaN
# 580782     NaN                  NaN     NaN     NaN
# 580783     NaN                  NaN     NaN     NaN
#
# [580784 rows x 22 columns]

# %%
customer_final.dtypes
# Out:
# customer_id                 object
# product_id                  object
# signup_date_time            object
# cancel_date_time            object
# chur                         int64
# signup_date         datetime64[ns]
# cancel_date         datetime64[ns]
# signup_year                  int64
# signup_month                 int64
# cancel_year                  int64
# cancel_month                 int64
# duration                     int64
# name                        object
# price                        int64
# billing_cycle                int64
# age                          int64
# agerange                  category
# gender                      object
# case_id                     object
# date_time                   object
# channel                     object
# reason                      object
# dtype: object

# %%
print(customer_final.isnull().sum())
# Out:
# customer_id              0
# product_id               0
# signup_date_time         0
# cancel_date_time    451191
# chur                     0
# signup_date              0
# cancel_date              0
# signup_year              0
# signup_month             0
# cancel_year              0
# cancel_month             0
# duration                 0
# name                     0
# price                    0
# billing_cycle            0
# age                      0
# agerange                 0
# gender                   0
# case_id             250272
# date_time           250272
# channel             250272
# reason              250272
# dtype: int64

# %%
customer_final[customer_final.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [customer_id, product_id, signup_date_time, cancel_date_time, chur, signup_date, cancel_date, signup_year, signup_month, cancel_year, cancel_month, duration, name, price, billing_cycle, age, agerange, gender, case_id, date_time, channel, reason]
# Index: []
#
# [0 rows x 22 columns]

# %%
customer_final.describe().T
# Out:
#                   count         mean         std     min     25%     50%  \
# chur           580784.0     0.223135    0.416348     0.0     0.0     0.0
# signup_year    580784.0  2019.700765    1.218363  2017.0  2019.0  2020.0
# signup_month   580784.0     5.609712    3.194347     1.0     3.0     5.0
# cancel_year    580784.0  2021.596726    0.886408  2017.0  2022.0  2022.0
# cancel_month   580784.0     2.371079    3.011829     1.0     1.0     1.0
# duration       580784.0   583.429530  427.360972     1.0   240.0   498.0
# price          580784.0   781.214143  524.226740   125.0   125.0  1200.0
# billing_cycle  580784.0     7.714749    5.364181     1.0     1.0    12.0
# age            580784.0    58.341015    8.505962    21.0    53.0    59.0
#
#                   75%     max
# chur              0.0     1.0
# signup_year    2021.0  2021.0
# signup_month      8.0    12.0
# cancel_year    2022.0  2022.0
# cancel_month      1.0    12.0
# duration        859.0  1826.0
# price          1200.0  1200.0
# billing_cycle    12.0    12.0
# age              64.0    78.0

# %%
#Observations
#the average customer age is 58.3 years
#the average subscription length is 583 days
#the average cancel month occurs in February
#the average signup month occurs in May

# %%
#Exploratory Data Analysis

# %%
customer_final.hist
customer_final.hist(figsize=(19,12), color="Blue")
# Out:
# array([[<AxesSubplot:title={'center':'chur'}>,
#         <AxesSubplot:title={'center':'signup_date'}>,
#         <AxesSubplot:title={'center':'cancel_date'}>],
#        [<AxesSubplot:title={'center':'signup_year'}>,
#         <AxesSubplot:title={'center':'signup_month'}>,
#         <AxesSubplot:title={'center':'cancel_year'}>],
#        [<AxesSubplot:title={'center':'cancel_month'}>,
#         <AxesSubplot:title={'center':'duration'}>,
#         <AxesSubplot:title={'center':'price'}>],
#        [<AxesSubplot:title={'center':'billing_cycle'}>,
#         <AxesSubplot:title={'center':'age'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
#Observations
#More customers signup in the first 6 months of very year
#The highest number of customers have cancelled in the last 6 months of 2021

# %%
p = sns.countplot(x='signup_month', data=customer_final[customer_final['reason'] == 'signup'], hue='gender')
p.set_title('New Signups by Gender per Month')
# Out:
# Text(0.5, 1.0, 'New Signups by Gender per Month')

# %%
p = sns.countplot(x='signup_year', data=customer_final[customer_final['reason'] == 'signup'], hue='gender')
p.set_title('New Signups by Gender per Year')
# Out:
# Text(0.5, 1.0, 'New Signups by Gender per Year')

# %%
p = sns.countplot(x='signup_month', data=customer_final[customer_final['reason'] == 'signup'], hue='signup_year')
p.set_title('New Signups by Month')
# Out:
# Text(0.5, 1.0, 'New Signups by Month')

# %%
p = sns.countplot(x='signup_year', data=customer_final[customer_final['reason'] == 'signup'], hue='name')
p.set_title('New Signups by Product per Year')
# Out:
# Text(0.5, 1.0, 'New Signups by Product per Year')

# %%
p = sns.countplot(x='signup_year', data=customer_final[customer_final['reason'] == 'signup'], hue='agerange')
p.set_title('New Signups by Product per Agerange')
# Out:
# Text(0.5, 1.0, 'New Signups by Product per Agerange')

# %%
p = sns.countplot(x='signup_month', data=customer_final[customer_final['reason'] == 'signup'], hue='name')
p.set_title('New Signups by Product per Month')
# Out:
# Text(0.5, 1.0, 'New Signups by Product per Month')

# %%
plt.figure(figsize=(10,5))
c=customer_final.corr()
sns.heatmap(c, cmap="Blues",annot=True)
c
plt.title("Correlation Heatmap of Customer Subscription Data")
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap of Customer Subscription Data')

# %%
#Observations
#churn strong correlations with signup_year, signup_month, cancel_year and cancel_month however we won't be including these in the model because they will skew the data

# %%
sns.pairplot(customer_final, hue = "chur", corner=True)

# %%
def probability_plot(columns):
    global customer_final
    customer_final.groupby(columns)["chur"].mean().plot(kind="barh",label="Churn Probability")
    plt.vlines(x=customer_final["chur"].mean(),ymin=-1, ymax=8, color="red",
               label="Average of Churn Probability",ls="--")
    plt.legend(bbox_to_anchor=(0.75,1.15),ncol=2, fancybox=True, shadow=True)
    plt.xlabel("Probability")
    plt.show()

# %%
probability_plot(["gender","name"])

# %%
probability_plot(["agerange","gender"])

# %%
probability_plot(["name","agerange"])

# %%
customer_final["cancel_date_time"] = pd.to_datetime(customer_final["cancel_date_time"])
groupby = customer_final.groupby([pd.Grouper(key="cancel_date_time", freq="MS")])["name"].value_counts().reset_index(name="num_customer")
groupby.columns = ["Cancel Date Time", "Product", "Number of New Customer"]
pivot = groupby.pivot(values="Number of New Customer",index="Cancel Date Time",columns="Product")
pivot.columns = ["Annual Subscription", "Monthly Subscription"]
pivot.index.freq= "MS"
pivot.plot()
plt.title("Number of Customer Churn")
plt.show()

# %%
customer_final
# Out:
#        customer_id product_id     signup_date_time    cancel_date_time  chur  \
# 0            C2448      prd_1  2017-01-01 10:35:09                 NaT     0
# 1            C2449      prd_1  2017-01-01 11:39:29 2021-09-05 10:00:02     1
# 2            C2450      prd_1  2017-01-01 11:42:00 2019-01-13 16:24:55     1
# 3            C2452      prd_1  2017-01-01 13:57:30 2021-06-28 18:06:01     1
# 4            C2453      prd_1  2017-01-01 15:26:14                 NaT     0
# ...            ...        ...                  ...                 ...   ...
# 580779     C511375      prd_2  2021-12-31 18:37:58                 NaT     0
# 580780     C511376      prd_2  2021-12-31 18:42:00                 NaT     0
# 580781     C511377      prd_2  2021-12-31 18:50:53                 NaT     0
# 580782     C511378      prd_2  2021-12-31 19:00:38                 NaT     0
# 580783     C511379      prd_2  2021-12-31 19:38:21                 NaT     0
#
#        signup_date cancel_date  signup_year  signup_month  cancel_year  ...  \
# 0       2017-01-01  2022-01-01         2017             1         2022  ...
# 1       2017-01-01  2021-09-05         2017             1         2021  ...
# 2       2017-01-01  2019-01-13         2017             1         2019  ...
# 3       2017-01-01  2021-06-28         2017             1         2021  ...
# 4       2017-01-01  2022-01-01         2017             1         2022  ...
# ...            ...         ...          ...           ...          ...  ...
# 580779  2021-12-31  2022-01-01         2021            12         2022  ...
# 580780  2021-12-31  2022-01-01         2021            12         2022  ...
# 580781  2021-12-31  2022-01-01         2021            12         2022  ...
# 580782  2021-12-31  2022-01-01         2021            12         2022  ...
# 580783  2021-12-31  2022-01-01         2021            12         2022  ...
#
#                         name  price billing_cycle  age  agerange  gender  \
# 0        annual_subscription   1200            12   76       65+  female
# 1        annual_subscription   1200            12   61     50-65    male
# 2        annual_subscription   1200            12   58     50-65  female
# 3        annual_subscription   1200            12   71       65+    male
# 4        annual_subscription   1200            12   56     50-65    male
# ...                      ...    ...           ...  ...       ...     ...
# 580779  monthly_subscription    125             1   53     50-65    male
# 580780  monthly_subscription    125             1   60     50-65    male
# 580781  monthly_subscription    125             1   67       65+  female
# 580782  monthly_subscription    125             1   49     35-50    male
# 580783  monthly_subscription    125             1   55     50-65    male
#
#        case_id            date_time channel  reason
# 0        CC101  2017-01-01 10:32:03   phone  signup
# 1        CC102  2017-01-01 11:35:47   phone  signup
# 2        CC103  2017-01-01 11:37:09   phone  signup
# 3        CC105  2017-01-01 13:52:22   phone  signup
# 4        CC106  2017-01-01 15:23:02   phone  signup
# ...        ...                  ...     ...     ...
# 580779     NaN                  NaN     NaN     NaN
# 580780     NaN                  NaN     NaN     NaN
# 580781     NaN                  NaN     NaN     NaN
# 580782     NaN                  NaN     NaN     NaN
# 580783     NaN                  NaN     NaN     NaN
#
# [580784 rows x 22 columns]

# %%
customer_final.drop(columns=['signup_date','cancel_date', 'signup_date_time', 'cancel_date_time', 'customer_id', 'product_id', 'date_time', 'case_id', 'signup_year', 'signup_month', 'cancel_year', 'cancel_month', 'age', 'channel', 'billing_cycle',], inplace=True)
customer_final.dtypes
# Out:
# chur           int64
# duration       int64
# name          object
# price          int64
# agerange    category
# gender        object
# reason        object
# dtype: object

# %%
customer_final.drop(columns=['reason'], inplace=True)

# %%
print(customer_final.isnull().sum())
# Out:
# chur        0
# duration    0
# name        0
# price       0
# agerange    0
# gender      0
# dtype: int64

# %%
#customer_final['channel'] = customer_final['channel'].fillna(2)
#customer_final['reason'] = customer_final['reason'].fillna(2)

# %%
customer_final['name'] = customer_final['name'].replace({"annual_subscription":0, "monthly_subscription":1})
customer_final['agerange'] = customer_final['agerange'].replace({"18-35":0, "35-50":1, "50-65":2, "65+":3})
customer_final['agerange'] = customer_final['agerange'].astype(int)
customer_final['gender'] = customer_final['gender'].replace({"male":0, "female":1})
#customer_final['channel'] = customer_final['channel'].replace({"phone":0, "email":1, "NaN":2})
#customer_final['reason'] = customer_final['reason'].replace({"support":0, "signup":1, "NaN":2})

# %%
customer_final
# Out:
#         chur  duration  name  price  agerange  gender
# 0          0      1826     0   1200         3       1
# 1          1      1708     0   1200         2       0
# 2          1       742     0   1200         2       1
# 3          1      1639     0   1200         3       0
# 4          0      1826     0   1200         2       0
# ...      ...       ...   ...    ...       ...     ...
# 580779     0         1     1    125         2       0
# 580780     0         1     1    125         2       0
# 580781     0         1     1    125         3       1
# 580782     0         1     1    125         1       0
# 580783     0         1     1    125         2       0
#
# [580784 rows x 6 columns]

# %%
customer_final.dtypes
# Out:
# chur        int64
# duration    int64
# name        int64
# price       int64
# agerange    int32
# gender      int64
# dtype: object

# %%
plt.figure(figsize=(30,20))
c=customer_final.corr()
sns.heatmap(c, cmap="Blues",annot=True)
c
plt.title("Correlation Heatmap of Customer Subscription Data")
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap of Customer Subscription Data')

# %%
#Train-test Split

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
#Here we'll scale the data to counter the imbalance that exist with customer churn or not

# %%
X = StandardScaler().fit_transform(customer_final.drop("chur",axis=1))
y = customer_final["chur"].values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3)

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier

from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import GridSearchCV

# %%
#As this is a classification prediction we'll be testing with MLP, Logistic Regression and Naive Bayes models

# %%
net = MLPClassifier()
net.hidden_layer_sizes=(30,60,30)
net.activation='relu'
net.solver='adam'
net.max_iter=30
net.verbose = True
net.batch_size = 1000

# %%
net.fit(X_train,y_train)
# Out:
# Iteration 1, loss = 0.51953232
# Iteration 2, loss = 0.51348644
# Iteration 3, loss = 0.51299219
# Iteration 4, loss = 0.51267803
# Iteration 5, loss = 0.51259544
# Iteration 6, loss = 0.51237037
# Iteration 7, loss = 0.51218095
# Iteration 8, loss = 0.51199211
# Iteration 9, loss = 0.51174280
# Iteration 10, loss = 0.51150231
# Iteration 11, loss = 0.51120954
# Iteration 12, loss = 0.51109759
# Iteration 13, loss = 0.51071832
# Iteration 14, loss = 0.51048884
# Iteration 15, loss = 0.51036854
# Iteration 16, loss = 0.51032515
# Iteration 17, loss = 0.51013885
# Iteration 18, loss = 0.51006395
# Iteration 19, loss = 0.50993810
# Iteration 20, loss = 0.50978664
# Iteration 21, loss = 0.50969966
# Iteration 22, loss = 0.50966974
# Iteration 23, loss = 0.50962430
# Iteration 24, loss = 0.50953933
# Iteration 25, loss = 0.50949540
# Iteration 26, loss = 0.50956082
# Iteration 27, loss = 0.50929129
# Iteration 28, loss = 0.50938767
# Iteration 29, loss = 0.50927349
# Iteration 30, loss = 0.50924095
# MLPClassifier(batch_size=1000, hidden_layer_sizes=(30, 60, 30), max_iter=30,
#               verbose=True)

# %%
net.score(X_test, y_test)
# Out:
# 0.7768945568080076

# %%
#plot_roc_curve(net, X_test,y_test)
#plt.show()

# %%
cr = pd.DataFrame(classification_report(net.predict(X_test), 
                                        y_test, digits=2,
                                        output_dict=True)).T

cr['support'] = cr.support.apply(int)

cr.style.background_gradient(cmap='viridis',
                             subset=pd.IndexSlice['0':'1', :'f1-score'])
# Out:
# <style type="text/css">
# #T_4d624_row0_col0, #T_4d624_row0_col1, #T_4d624_row0_col2 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_4d624_row1_col0, #T_4d624_row1_col1, #T_4d624_row1_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4d624">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4d624_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_4d624_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_4d624_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_4d624_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4d624_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4d624_row0_col0" class="data row0 col0" >0.999202</td>
#       <td id="T_4d624_row0_col1" class="data row0 col1" >0.777219</td>
#       <td id="T_4d624_row0_col2" class="data row0 col2" >0.874341</td>
#       <td id="T_4d624_row0_col3" class="data row0 col3" >174005</td>
#     </tr>
#     <tr>
#       <th id="T_4d624_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4d624_row1_col0" class="data row1 col0" >0.003163</td>
#       <td id="T_4d624_row1_col1" class="data row1 col1" >0.532468</td>
#       <td id="T_4d624_row1_col2" class="data row1 col2" >0.006289</td>
#       <td id="T_4d624_row1_col3" class="data row1 col3" >231</td>
#     </tr>
#     <tr>
#       <th id="T_4d624_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_4d624_row2_col0" class="data row2 col0" >0.776895</td>
#       <td id="T_4d624_row2_col1" class="data row2 col1" >0.776895</td>
#       <td id="T_4d624_row2_col2" class="data row2 col2" >0.776895</td>
#       <td id="T_4d624_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_4d624_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_4d624_row3_col0" class="data row3 col0" >0.501182</td>
#       <td id="T_4d624_row3_col1" class="data row3 col1" >0.654843</td>
#       <td id="T_4d624_row3_col2" class="data row3 col2" >0.440315</td>
#       <td id="T_4d624_row3_col3" class="data row3 col3" >174236</td>
#     </tr>
#     <tr>
#       <th id="T_4d624_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_4d624_row4_col0" class="data row4 col0" >0.997882</td>
#       <td id="T_4d624_row4_col1" class="data row4 col1" >0.776895</td>
#       <td id="T_4d624_row4_col2" class="data row4 col2" >0.873190</td>
#       <td id="T_4d624_row4_col3" class="data row4 col3" >174236</td>
#     </tr>
#   </tbody>
# </table>

# %%
lin_model = LogisticRegression(solver='liblinear')
lin_model.fit(X_train, y_train)
lin_model.score(X_test, y_test)
# Out:
# 0.7768084666773801

# %%
#plot_roc_curve(lin_model, X_test,y_test)
#plt.show()

# %%
crlin = pd.DataFrame(classification_report(lin_model.predict(X_test), 
                                        y_test, digits=2,
                                        output_dict=True)).T

crlin['support'] = cr.support.apply(int)

crlin.style.background_gradient(cmap='viridis',
                             subset=pd.IndexSlice['0':'1', :'f1-score'])
# Out:
# <style type="text/css">
# #T_a6f7b_row0_col0, #T_a6f7b_row0_col1, #T_a6f7b_row0_col2 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_a6f7b_row1_col0, #T_a6f7b_row1_col1, #T_a6f7b_row1_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a6f7b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a6f7b_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_a6f7b_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_a6f7b_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_a6f7b_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a6f7b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a6f7b_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_a6f7b_row0_col1" class="data row0 col1" >0.776808</td>
#       <td id="T_a6f7b_row0_col2" class="data row0 col2" >0.874386</td>
#       <td id="T_a6f7b_row0_col3" class="data row0 col3" >174005</td>
#     </tr>
#     <tr>
#       <th id="T_a6f7b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a6f7b_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_a6f7b_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_a6f7b_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_a6f7b_row1_col3" class="data row1 col3" >231</td>
#     </tr>
#     <tr>
#       <th id="T_a6f7b_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_a6f7b_row2_col0" class="data row2 col0" >0.776808</td>
#       <td id="T_a6f7b_row2_col1" class="data row2 col1" >0.776808</td>
#       <td id="T_a6f7b_row2_col2" class="data row2 col2" >0.776808</td>
#       <td id="T_a6f7b_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a6f7b_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_a6f7b_row3_col0" class="data row3 col0" >0.500000</td>
#       <td id="T_a6f7b_row3_col1" class="data row3 col1" >0.388404</td>
#       <td id="T_a6f7b_row3_col2" class="data row3 col2" >0.437193</td>
#       <td id="T_a6f7b_row3_col3" class="data row3 col3" >174236</td>
#     </tr>
#     <tr>
#       <th id="T_a6f7b_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_a6f7b_row4_col0" class="data row4 col0" >1.000000</td>
#       <td id="T_a6f7b_row4_col1" class="data row4 col1" >0.776808</td>
#       <td id="T_a6f7b_row4_col2" class="data row4 col2" >0.874386</td>
#       <td id="T_a6f7b_row4_col3" class="data row4 col3" >174236</td>
#     </tr>
#   </tbody>
# </table>

# %%
model = GaussianNB()
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.7768084666773801

# %%
#plot_roc_curve(model, X_test,y_test)
#plt.show()

# %%
#Predict Score
crmodel = pd.DataFrame(classification_report(model.predict(X_test), 
                                        y_test, digits=2,
                                        output_dict=True)).T

crmodel['support'] = crmodel.support.apply(int)

crmodel.style.background_gradient(cmap='viridis',
                             subset=pd.IndexSlice['0':'1', :'f1-score'])
# Out:
# <style type="text/css">
# #T_a333e_row0_col0, #T_a333e_row0_col1, #T_a333e_row0_col2 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_a333e_row1_col0, #T_a333e_row1_col1, #T_a333e_row1_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a333e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a333e_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_a333e_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_a333e_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_a333e_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a333e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a333e_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_a333e_row0_col1" class="data row0 col1" >0.776808</td>
#       <td id="T_a333e_row0_col2" class="data row0 col2" >0.874386</td>
#       <td id="T_a333e_row0_col3" class="data row0 col3" >174236</td>
#     </tr>
#     <tr>
#       <th id="T_a333e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a333e_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_a333e_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_a333e_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_a333e_row1_col3" class="data row1 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a333e_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_a333e_row2_col0" class="data row2 col0" >0.776808</td>
#       <td id="T_a333e_row2_col1" class="data row2 col1" >0.776808</td>
#       <td id="T_a333e_row2_col2" class="data row2 col2" >0.776808</td>
#       <td id="T_a333e_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_a333e_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_a333e_row3_col0" class="data row3 col0" >0.500000</td>
#       <td id="T_a333e_row3_col1" class="data row3 col1" >0.388404</td>
#       <td id="T_a333e_row3_col2" class="data row3 col2" >0.437193</td>
#       <td id="T_a333e_row3_col3" class="data row3 col3" >174236</td>
#     </tr>
#     <tr>
#       <th id="T_a333e_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_a333e_row4_col0" class="data row4 col0" >1.000000</td>
#       <td id="T_a333e_row4_col1" class="data row4 col1" >0.776808</td>
#       <td id="T_a333e_row4_col2" class="data row4 col2" >0.874386</td>
#       <td id="T_a333e_row4_col3" class="data row4 col3" >174236</td>
#     </tr>
#   </tbody>
# </table>

# %%
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import average_precision_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

# %%
rfmodel = RandomForestClassifier(random_state=1)
print(rfmodel)
# Out:
# RandomForestClassifier(random_state=1)

# %%
rfmodel.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=1)

# %%
def show_summary_report(actual, prediction):

    if isinstance(actual, pd.Series):
        actual = actual.values.astype(int)
    prediction = prediction.astype(float)
    prediction_int = np.round(prediction)

    print('Accuracy : %.4f [TP / N]         Best: 1, Worst: 0' %
          accuracy_score(actual, prediction_int))
    msg = '           Proportion of predicted labels that match the true labels.'
    print(msg)
    print('Precision: %.4f [TP / (TP + FP)] Best: 1, Worst: 0' %
          precision_score(actual, prediction_int))
    msg = '           Not to label a negative sample as positive.'
    print(msg)
    print('Recall   : %.4f [TP / (TP + FN)] Best: 1, Worst: 0' %
          recall_score(actual, prediction_int))
    msg = '           Find all the positive samples.'
    print(msg)
    print('ROC AUC  : %.4f                  Best: 1, Worst: < 0.5' %
          roc_auc_score(actual, prediction))
    print('-' * 80)
    print('TP: True Positives, FP: False Positives,')
    print('TN: True Negatives, FN: False Negatives,')
    print('N: Number of samples')

    # Confusion Matrix
    mat = confusion_matrix(actual, prediction_int)

    # Precision/Recall
    precision, recall, _ = precision_recall_curve(actual, prediction)

    # Compute ROC curve and ROC area
    fpr, tpr, _ = roc_curve(actual, prediction)
    roc_auc = auc(fpr, tpr)

    # plot
    fig, ax = plt.subplots(1, 3, figsize=(18, 6))
    fig.subplots_adjust(left=0.02, right=0.98, wspace=0.2)

    # Confusion Matrix
    sns.heatmap(mat.T, square=True, annot=True, fmt='d',
                cbar=False, cmap='Blues', ax=ax[0])

    ax[0].set_title('Confusion Matrix')
    ax[0].set_xlabel('True label')
    ax[0].set_ylabel('Predicted label')

    # Precision/Recall
    step_kwargs = {'step': 'post'}
    ax[1].step(recall, precision, color='b', alpha=0.2, where='post')
    ax[1].fill_between(recall, precision, alpha=0.2, color='b', **step_kwargs)
    ax[1].set_ylim([0.0, 1.0])
    ax[1].set_xlim([0.0, 1.0])
    ax[1].set_xlabel('Recall')
    ax[1].set_ylabel('Precision')
    ax[1].set_title('2-class Precision-Recall curve')

    # ROC
    ax[2].plot(fpr, tpr, color='darkorange', lw=2,
               label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax[2].plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    ax[2].set_xlim([0.0, 1.0])
    ax[2].set_ylim([0.0, 1.0])
    ax[2].set_xlabel('False Positive Rate')
    ax[2].set_ylabel('True Positive Rate')
    ax[2].set_title('Receiver Operating Characteristic')
    ax[2].legend(loc='lower right')

    plt.show()

# %%
y_train_prob = rfmodel.predict_proba(X_train)[:,1]

# %%
show_summary_report(y_train, y_train_prob)
# Out:
# Accuracy : 0.7908 [TP / N]         Best: 1, Worst: 0
#            Proportion of predicted labels that match the true labels.
# Precision: 0.6228 [TP / (TP + FP)] Best: 1, Worst: 0
#            Not to label a negative sample as positive.
# Recall   : 0.1581 [TP / (TP + FN)] Best: 1, Worst: 0
#            Find all the positive samples.
# ROC AUC  : 0.7420                  Best: 1, Worst: < 0.5
# --------------------------------------------------------------------------------
# TP: True Positives, FP: False Positives,
# TN: True Negatives, FN: False Negatives,
# N: Number of samples

# %%
crrf = pd.DataFrame(classification_report(rfmodel.predict(X_test), 
                                        y_test, digits=2,
                                        output_dict=True)).T

crrf['support'] = crrf.support.apply(int)

crrf.style.background_gradient(cmap='viridis',
                             subset=pd.IndexSlice['0':'1', :'f1-score'])
# Out:
# <style type="text/css">
# #T_c0106_row0_col0, #T_c0106_row0_col1, #T_c0106_row0_col2 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_c0106_row1_col0, #T_c0106_row1_col1, #T_c0106_row1_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c0106">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c0106_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_c0106_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_c0106_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_c0106_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c0106_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c0106_row0_col0" class="data row0 col0" >0.960494</td>
#       <td id="T_c0106_row0_col1" class="data row0 col1" >0.791921</td>
#       <td id="T_c0106_row0_col2" class="data row0 col2" >0.868100</td>
#       <td id="T_c0106_row0_col3" class="data row0 col3" >164159</td>
#     </tr>
#     <tr>
#       <th id="T_c0106_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c0106_row1_col0" class="data row1 col0" >0.121631</td>
#       <td id="T_c0106_row1_col1" class="data row1 col1" >0.469386</td>
#       <td id="T_c0106_row1_col2" class="data row1 col2" >0.193199</td>
#       <td id="T_c0106_row1_col3" class="data row1 col3" >10077</td>
#     </tr>
#     <tr>
#       <th id="T_c0106_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_c0106_row2_col0" class="data row2 col0" >0.773267</td>
#       <td id="T_c0106_row2_col1" class="data row2 col1" >0.773267</td>
#       <td id="T_c0106_row2_col2" class="data row2 col2" >0.773267</td>
#       <td id="T_c0106_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_c0106_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_c0106_row3_col0" class="data row3 col0" >0.541063</td>
#       <td id="T_c0106_row3_col1" class="data row3 col1" >0.630653</td>
#       <td id="T_c0106_row3_col2" class="data row3 col2" >0.530650</td>
#       <td id="T_c0106_row3_col3" class="data row3 col3" >174236</td>
#     </tr>
#     <tr>
#       <th id="T_c0106_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_c0106_row4_col0" class="data row4 col0" >0.911978</td>
#       <td id="T_c0106_row4_col1" class="data row4 col1" >0.773267</td>
#       <td id="T_c0106_row4_col2" class="data row4 col2" >0.829067</td>
#       <td id="T_c0106_row4_col3" class="data row4 col3" >174236</td>
#     </tr>
#   </tbody>
# </table>

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtmodel = DecisionTreeClassifier()
print(dtmodel)
# Out:
# DecisionTreeClassifier()

# %%
dtmodel.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
def show_summary_report(actual, prediction):

    if isinstance(actual, pd.Series):
        actual = actual.values.astype(int)
    prediction = prediction.astype(float)
    prediction_int = np.round(prediction)

    print('Accuracy : %.4f [TP / N]         Best: 1, Worst: 0' %
          accuracy_score(actual, prediction_int))
    msg = '           Proportion of predicted labels that match the true labels.'
    print(msg)
    print('Precision: %.4f [TP / (TP + FP)] Best: 1, Worst: 0' %
          precision_score(actual, prediction_int))
    msg = '           Not to label a negative sample as positive.'
    print(msg)
    print('Recall   : %.4f [TP / (TP + FN)] Best: 1, Worst: 0' %
          recall_score(actual, prediction_int))
    msg = '           Find all the positive samples.'
    print(msg)
    print('ROC AUC  : %.4f                  Best: 1, Worst: < 0.5' %
          roc_auc_score(actual, prediction))
    print('-' * 80)
    print('TP: True Positives, FP: False Positives,')
    print('TN: True Negatives, FN: False Negatives,')
    print('N: Number of samples')

    # Confusion Matrix
    mat = confusion_matrix(actual, prediction_int)

    # Precision/Recall
    precision, recall, _ = precision_recall_curve(actual, prediction)

    # Compute ROC curve and ROC area
    fpr, tpr, _ = roc_curve(actual, prediction)
    roc_auc = auc(fpr, tpr)

    # plot
    fig, ax = plt.subplots(1, 3, figsize=(18, 6))
    fig.subplots_adjust(left=0.02, right=0.98, wspace=0.2)

    # Confusion Matrix
    sns.heatmap(mat.T, square=True, annot=True, fmt='d',
                cbar=False, cmap='Blues', ax=ax[0])

    ax[0].set_title('Confusion Matrix')
    ax[0].set_xlabel('True label')
    ax[0].set_ylabel('Predicted label')

    # Precision/Recall
    step_kwargs = {'step': 'post'}
    ax[1].step(recall, precision, color='b', alpha=0.2, where='post')
    ax[1].fill_between(recall, precision, alpha=0.2, color='b', **step_kwargs)
    ax[1].set_ylim([0.0, 1.0])
    ax[1].set_xlim([0.0, 1.0])
    ax[1].set_xlabel('Recall')
    ax[1].set_ylabel('Precision')
    ax[1].set_title('2-class Precision-Recall curve')

    # ROC
    ax[2].plot(fpr, tpr, color='darkorange', lw=2,
               label='ROC curve (AUC = %0.2f)' % roc_auc)
    ax[2].plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    ax[2].set_xlim([0.0, 1.0])
    ax[2].set_ylim([0.0, 1.0])
    ax[2].set_xlabel('False Positive Rate')
    ax[2].set_ylabel('True Positive Rate')
    ax[2].set_title('Receiver Operating Characteristic')
    ax[2].legend(loc='lower right')

    plt.show()

# %%
y_train_pred = dtmodel.predict_proba(X_train)[:,1]

# %%
show_summary_report(y_train, y_train_pred)
# Out:
# Accuracy : 0.7908 [TP / N]         Best: 1, Worst: 0
#            Proportion of predicted labels that match the true labels.
# Precision: 0.6377 [TP / (TP + FP)] Best: 1, Worst: 0
#            Not to label a negative sample as positive.
# Recall   : 0.1444 [TP / (TP + FN)] Best: 1, Worst: 0
#            Find all the positive samples.
# ROC AUC  : 0.7431                  Best: 1, Worst: < 0.5
# --------------------------------------------------------------------------------
# TP: True Positives, FP: False Positives,
# TN: True Negatives, FN: False Negatives,
# N: Number of samples

# %%
crdt = pd.DataFrame(classification_report(dtmodel.predict(X_test), 
                                        y_test, digits=2,
                                        output_dict=True)).T

crdt['support'] = crdt.support.apply(int)

crdt.style.background_gradient(cmap='viridis',
                             subset=pd.IndexSlice['0':'1', :'f1-score'])
# Out:
# <style type="text/css">
# #T_9ddda_row0_col0, #T_9ddda_row0_col1, #T_9ddda_row0_col2 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_9ddda_row1_col0, #T_9ddda_row1_col1, #T_9ddda_row1_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_9ddda">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9ddda_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_9ddda_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_9ddda_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_9ddda_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9ddda_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9ddda_row0_col0" class="data row0 col0" >0.965696</td>
#       <td id="T_9ddda_row0_col1" class="data row0 col1" >0.790594</td>
#       <td id="T_9ddda_row0_col2" class="data row0 col2" >0.869416</td>
#       <td id="T_9ddda_row0_col3" class="data row0 col3" >165325</td>
#     </tr>
#     <tr>
#       <th id="T_9ddda_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9ddda_row1_col0" class="data row1 col0" >0.109751</td>
#       <td id="T_9ddda_row1_col1" class="data row1 col1" >0.478959</td>
#       <td id="T_9ddda_row1_col2" class="data row1 col2" >0.178581</td>
#       <td id="T_9ddda_row1_col3" class="data row1 col3" >8911</td>
#     </tr>
#     <tr>
#       <th id="T_9ddda_level0_row2" class="row_heading level0 row2" >accuracy</th>
#       <td id="T_9ddda_row2_col0" class="data row2 col0" >0.774656</td>
#       <td id="T_9ddda_row2_col1" class="data row2 col1" >0.774656</td>
#       <td id="T_9ddda_row2_col2" class="data row2 col2" >0.774656</td>
#       <td id="T_9ddda_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_9ddda_level0_row3" class="row_heading level0 row3" >macro avg</th>
#       <td id="T_9ddda_row3_col0" class="data row3 col0" >0.537723</td>
#       <td id="T_9ddda_row3_col1" class="data row3 col1" >0.634776</td>
#       <td id="T_9ddda_row3_col2" class="data row3 col2" >0.523999</td>
#       <td id="T_9ddda_row3_col3" class="data row3 col3" >174236</td>
#     </tr>
#     <tr>
#       <th id="T_9ddda_level0_row4" class="row_heading level0 row4" >weighted avg</th>
#       <td id="T_9ddda_row4_col0" class="data row4 col0" >0.921920</td>
#       <td id="T_9ddda_row4_col1" class="data row4 col1" >0.774656</td>
#       <td id="T_9ddda_row4_col2" class="data row4 col2" >0.834085</td>
#       <td id="T_9ddda_row4_col3" class="data row4 col3" >174236</td>
#     </tr>
#   </tbody>
# </table>

# %%
yhat_pp_lr = lin_model.predict_proba(X_test)[:,1]
yhat_pp_nb = model.predict_proba(X_test)[:,1]
yhat_pp_nt = net.predict_proba(X_test)[:,1]
yhat_pp_rf = rfmodel.predict_proba(X_test)[:,1]
yhat_pp_dt = dtmodel.predict_proba(X_test)[:,1]
fpr, tpr, _ = roc_curve(y_test, yhat_pp_lr)
#fpr_svc, tpr_svc, _ = roc_curve(y_test, yhat_pp_svc)
fpr_nb, tpr_nb, _ = roc_curve(y_test, yhat_pp_nb)
fpr_nt, tpr_nt, _ = roc_curve(y_test, yhat_pp_nt)
fpr_rf, tpr_rf, _ = roc_curve(y_test, yhat_pp_rf)
fpr_dt, tpr_dt, _ = roc_curve(y_test, yhat_pp_dt)

plt.figure(figsize=[10,10])
lw = 2
plt.plot(fpr, tpr, label='ROC curve Logistic (area = %0.2f)' % auc(fpr, tpr), linewidth=4, color='green')
plt.plot(fpr_nb, tpr_nb, label='ROC curve NB (area = %0.2f)' % auc(fpr_nb, tpr_nb), linewidth=4, color='darkblue')
plt.plot(fpr_nt, tpr_nt, label='ROC curve NT (area = %0.2f)' % auc(fpr_nt, tpr_nt), linewidth=4, color='black')
plt.plot(fpr_rf, tpr_rf, label='ROC curve RF (area = %0.2f)' % auc(fpr_rf, tpr_rf), linewidth=4, color='yellow')
plt.plot(fpr_dt, tpr_dt, label='ROC curve DT (area = %0.2f)' % auc(fpr_dt, tpr_dt), linewidth=4, color='darkred')


plt.plot([0, 1], [0, 1], color = 'orange', lw = lw, linestyle = '--')
plt.xlim([-0.05, 1.0])
plt.ylim([-0.05, 1.05])
plt.xlabel('False Positive Rate', fontsize=18)
plt.ylabel('True Positive Rate', fontsize=18)
plt.title('Receiver operating characteristic: Customer Churn', fontsize=18)
plt.legend(loc="lower right")
plt.show()

# %%
#Time Series Analysis (to predict monthly subscriptions)

# %%
customer_cases
# Out:
#          case_id            date_time customer_id channel   reason
# 1          CC101  2017-01-01 10:32:03       C2448   phone   signup
# 2          CC102  2017-01-01 11:35:47       C2449   phone   signup
# 3          CC103  2017-01-01 11:37:09       C2450   phone   signup
# 4          CC104  2017-01-01 13:28:14       C2451   phone   signup
# 5          CC105  2017-01-01 13:52:22       C2452   phone   signup
# ...          ...                  ...         ...     ...      ...
# 330508  CC330608  2021-12-31 19:16:28     C173079   email  support
# 330509  CC330609  2021-12-31 19:36:42     C497581   email  support
# 330510  CC330610  2021-12-31 20:30:02     C127630   email  support
# 330511  CC330611  2021-12-31 21:30:00     C497538   email  support
# 330512  CC330612  2022-01-01 06:32:53     C485032   phone  support
#
# [330512 rows x 5 columns]

# %%
customer_cases['date'] = customer_cases['date_time'].astype('datetime64').dt.date.astype('datetime64')
customer_cases.drop(columns=['date_time'], inplace=True)

# %%
customer_cases.describe().T
# Out:
#               count  unique                  top    freq      first       last
# case_id      330512  330512                CC101       1        NaT        NaT
# customer_id  330512  258660               C20510       5        NaT        NaT
# channel      330512       2                phone  286840        NaT        NaT
# reason       330512       2              support  200985        NaT        NaT
# date         330512    1827  2021-06-14 00:00:00     522 2017-01-01 2022-01-01

# %%
customer_cases['year'] = customer_cases['date'].dt.year.astype('int64')
customer_cases['month'] = customer_cases['date'].dt.month.astype('int64')

customer_cases.head()
# Out:
#   case_id customer_id channel  reason       date  year  month
# 1   CC101       C2448   phone  signup 2017-01-01  2017      1
# 2   CC102       C2449   phone  signup 2017-01-01  2017      1
# 3   CC103       C2450   phone  signup 2017-01-01  2017      1
# 4   CC104       C2451   phone  signup 2017-01-01  2017      1
# 5   CC105       C2452   phone  signup 2017-01-01  2017      1

# %%
unique_cust_case_year_month = customer_cases.drop_duplicates(subset=['customer_id', 'year', 'month'], keep='first')
cust_sub = pd.merge(unique_cust_case_year_month, customer_product, on=['customer_id'])
cust_sub
# Out:
#          case_id customer_id channel   reason       date  year  month  \
# 0          CC101       C2448   phone   signup 2017-01-01  2017      1
# 1          CC102       C2449   phone   signup 2017-01-01  2017      1
# 2          CC103       C2450   phone   signup 2017-01-01  2017      1
# 3          CC104       C2451   phone   signup 2017-01-01  2017      1
# 4         CC4491       C2451   phone  support 2017-03-31  2017      3
# ...          ...         ...     ...      ...        ...   ...    ...
# 324585  CC330604     C484812   email  support 2021-12-31  2021     12
# 324586  CC330608     C173079   email  support 2021-12-31  2021     12
# 324587  CC330609     C497581   email  support 2021-12-31  2021     12
# 324588  CC330611     C497538   email  support 2021-12-31  2021     12
# 324589  CC330612     C485032   phone  support 2022-01-01  2022      1
#
#        product_id     signup_date_time     cancel_date_time  chur signup_date  \
# 0           prd_1  2017-01-01 10:35:09                  NaN     0  2017-01-01
# 1           prd_1  2017-01-01 11:39:29  2021-09-05 10:00:02     1  2017-01-01
# 2           prd_1  2017-01-01 11:42:00  2019-01-13 16:24:55     1  2017-01-01
# 3           prd_2  2017-01-01 13:32:08                  NaN     0  2017-01-01
# 4           prd_2  2017-01-01 13:32:08                  NaN     0  2017-01-01
# ...           ...                  ...                  ...   ...         ...
# 324585      prd_2  2021-09-07 17:38:49                  NaN     0  2021-09-07
# 324586      prd_1  2018-05-22 17:27:36                  NaN     0  2018-05-22
# 324587      prd_2  2021-10-25 14:12:27                  NaN     0  2021-10-25
# 324588      prd_2  2021-10-25 13:19:07                  NaN     0  2021-10-25
# 324589      prd_2  2021-09-08 13:48:23                  NaN     0  2021-09-08
#
#        cancel_date  signup_year  signup_month  cancel_year  cancel_month  \
# 0       2022-01-01         2017             1         2022             1
# 1       2021-09-05         2017             1         2021             9
# 2       2019-01-13         2017             1         2019             1
# 3       2022-01-01         2017             1         2022             1
# 4       2022-01-01         2017             1         2022             1
# ...            ...          ...           ...          ...           ...
# 324585  2022-01-01         2021             9         2022             1
# 324586  2022-01-01         2018             5         2022             1
# 324587  2022-01-01         2021            10         2022             1
# 324588  2022-01-01         2021            10         2022             1
# 324589  2022-01-01         2021             9         2022             1
#
#         duration
# 0           1826
# 1           1708
# 2            742
# 3           1826
# 4           1826
# ...          ...
# 324585       116
# 324586      1320
# 324587        68
# 324588        68
# 324589       115
#
# [324590 rows x 18 columns]

# %%
signup_df= cust_sub[cust_sub['reason']=='signup'].groupby(['year', 'month']).size().reset_index(name='signup')
signup_df
# Out:
#     year  month  signup
# 0   2017      1    1306
# 1   2017      2    1183
# 2   2017      3    1367
# 3   2017      4    1182
# 4   2017      5    1299
# 5   2017      6     990
# 6   2017      7     909
# 7   2017      8     721
# 8   2017      9     513
# 9   2017     10     431
# 10  2017     11     336
# 11  2017     12     188
# 12  2018      1    1888
# 13  2018      2    1724
# 14  2018      3    1912
# 15  2018      4    1842
# 16  2018      5    1806
# 17  2018      6    1571
# 18  2018      7    1506
# 19  2018      8    1347
# 20  2018      9    1036
# 21  2018     10     991
# 22  2018     11     763
# 23  2018     12     534
# 24  2019      1    3035
# 25  2019      2    2616
# 26  2019      3    3001
# 27  2019      4    3048
# 28  2019      5    3015
# 29  2019      6    2679
# 30  2019      7    2806
# 31  2019      8    2416
# 32  2019      9    2211
# 33  2019     10    2034
# 34  2019     11    1592
# 35  2019     12    1589
# 36  2020      1    3675
# 37  2020      2    3292
# 38  2020      3    3575
# 39  2020      4    3552
# 40  2020      5    3371
# 41  2020      6    3401
# 42  2020      7    3138
# 43  2020      8    2744
# 44  2020      9    2408
# 45  2020     10    2128
# 46  2020     11    1708
# 47  2020     12    1534
# 48  2021      1    3891
# 49  2021      2    3655
# 50  2021      3    4321
# 51  2021      4    4119
# 52  2021      5    3920
# 53  2021      6    3733
# 54  2021      7    3278
# 55  2021      8    2925
# 56  2021      9    2515
# 57  2021     10    2024
# 58  2021     11    1767
# 59  2021     12    1466

# %%
cust_cancel_df = cust_sub[cust_sub['cancel_year']!=2022].groupby(['cancel_year', 'cancel_month']).size().reset_index(name='cust_cancel')
cust_cancel_df
# Out:
#     cancel_year  cancel_month  cust_cancel
# 0          2017             1           13
# 1          2017             2           20
# 2          2017             3           62
# 3          2017             4           75
# 4          2017             5          115
# 5          2017             6          119
# 6          2017             7          152
# 7          2017             8          153
# 8          2017             9          146
# 9          2017            10          192
# 10         2017            11          160
# 11         2017            12          169
# 12         2018             1          238
# 13         2018             2          221
# 14         2018             3          286
# 15         2018             4          288
# 16         2018             5          375
# 17         2018             6          410
# 18         2018             7          414
# 19         2018             8          443
# 20         2018             9          447
# 21         2018            10          497
# 22         2018            11          492
# 23         2018            12          568
# 24         2019             1          544
# 25         2019             2          587
# 26         2019             3          664
# 27         2019             4          729
# 28         2019             5          801
# 29         2019             6          879
# 30         2019             7          976
# 31         2019             8         1042
# 32         2019             9         1103
# 33         2019            10         1062
# 34         2019            11         1097
# 35         2019            12         1185
# 36         2020             1         1212
# 37         2020             2         1262
# 38         2020             3         1417
# 39         2020             4         1452
# 40         2020             5         1725
# 41         2020             6         1608
# 42         2020             7         1811
# 43         2020             8         1871
# 44         2020             9         1911
# 45         2020            10         1989
# 46         2020            11         2079
# 47         2020            12         2250
# 48         2021             1         2269
# 49         2021             2         2176
# 50         2021             3         2815
# 51         2021             4         2776
# 52         2021             5         3153
# 53         2021             6         3103
# 54         2021             7         3390
# 55         2021             8         3492
# 56         2021             9         3562
# 57         2021            10         3783
# 58         2021            11         3778
# 59         2021            12         3889

# %%
year = np.array([2017, 2018, 2019, 2020, 2021])
month = np.arange(1, 13)
total_sub = np.zeros((60,4))
idx=0

for y in year:
    for m in month:
        total_sub[idx][0] = y
        total_sub[idx][1] = m
        if m == 12:
            total_sub[idx][2] = cust_sub[(cust_sub['signup_date']<dt(y+1,1,1))&(cust_sub['cancel_date']>=dt(y,m,1))&(cust_sub['signup_month']==m)&(cust_sub['product_id']=='prd_1')].count().tolist()[0]
            total_sub[idx][3] = cust_sub[(cust_sub['signup_date']<dt(y+1,1,1))&(cust_sub['cancel_date']>=dt(y,m,1))&(cust_sub['product_id']=='prd_2')].count().tolist()[0]
        else:
            total_sub[idx][2] = cust_sub[(cust_sub['signup_date']<dt(y,m+1,1))&(cust_sub['cancel_date']>=dt(y,m,1))&(cust_sub['signup_month']==m)&(cust_sub['product_id']=='prd_1')].count().tolist()[0]
            total_sub[idx][3] = cust_sub[(cust_sub['signup_date']<dt(y,m+1,1))&(cust_sub['cancel_date']>=dt(y,m,1))&(cust_sub['product_id']=='prd_2')].count().tolist()[0]
        idx+=1
total_sub_df = pd.DataFrame(total_sub, columns=['sub_year','sub_month','prod_1_sub','prod_2_sub'], dtype='int64')
total_sub_df
# Out:
#     sub_year  sub_month  prod_1_sub  prod_2_sub
# 0       2017          1        2285         630
# 1       2017          2        2078        1164
# 2       2017          3        2388        1825
# 3       2017          4        2109        2427
# 4       2017          5        2237        3028
# 5       2017          6        1805        3471
# 6       2017          7        1582        3853
# 7       2017          8        1318        4173
# 8       2017          9         980        4354
# 9       2017         10         768        4541
# 10      2017         11         635        4633
# 11      2017         12         367        4689
# 12      2018          1        5333        5802
# 13      2018          2        4793        6754
# 14      2018          3        5479        7851
# 15      2018          4        5068        8807
# 16      2018          5        5162        9844
# 17      2018          6        4378       10676
# 18      2018          7        4061       11431
# 19      2018          8        3569       12104
# 20      2018          9        2711       12589
# 21      2018         10        2337       13024
# 22      2018         11        1847       13303
# 23      2018         12        1312       13482
# 24      2019          1        9686       15283
# 25      2019          2        8619       16783
# 26      2019          3        9643       18552
# 27      2019          4        9497       20254
# 28      2019          5        9457       22074
# 29      2019          6        8244       23501
# 30      2019          7        8154       25006
# 31      2019          8        7112       26237
# 32      2019          9        5895       27221
# 33      2019         10        5366       28222
# 34      2019         11        4213       28915
# 35      2019         12        3609       29520
# 36      2020          1       13415       32965
# 37      2020          2       12059       35910
# 38      2020          3       13227       39271
# 39      2020          4       13051       42540
# 40      2020          5       12671       45628
# 41      2020          6       11688       48506
# 42      2020          7       11145       51337
# 43      2020          8        9850       53581
# 44      2020          9        8502       55375
# 45      2020         10        7463       56914
# 46      2020         11        5946       57923
# 47      2020         12        5180       58639
# 48      2021          1       15283       68423
# 49      2021          2       13697       77687
# 50      2021          3       15199       88689
# 51      2021          4       14871       98425
# 52      2021          5       14382      107000
# 53      2021          6       13129      113972
# 54      2021          7       12304      119497
# 55      2021          8       10642      123318
# 56      2021          9        9146      125494
# 57      2021         10        7822      126197
# 58      2021         11        6147      125821
# 59      2021         12        5263      124562

# %%
unique_cust_case = customer_cases.drop_duplicates(subset=['customer_id'], keep='first')
existing_cust = len(customer_product[~customer_product['customer_id'].isin(customer_cases['customer_id'])])
total_cust_count = unique_cust_case[(unique_cust_case['year']==2017)&(unique_cust_case['month']==1)]['customer_id'].count()+existing_cust
total_cust = []

for y in year:
    for m in month:
        if y==2017 and m==1:
            total_cust.append(total_cust_count)
        else:
            total_cust_count = total_cust_count + signup_df[(signup_df['year']==y)&(signup_df['month']==m)]['signup'].tolist()[0] \
                               - cust_cancel_df[(cust_cancel_df['cancel_year']==y)&(cust_cancel_df['cancel_month']==m)]['cust_cancel'].tolist()[0]
            total_cust.append(total_cust_count)

# %%
cust_df = pd.merge(signup_df, cust_cancel_df, left_on=['year','month'], right_on=['cancel_year', 'cancel_month'])
cust_df = pd.merge(cust_df, total_sub_df, left_on=['year','month'], right_on=['sub_year', 'sub_month'])
cust_df['total_cust'] = total_cust

# %%
signup_rate = np.array(cust_df[1:]['signup']) / np.array(cust_df[:-1]['total_cust'])
signup_rate = np.insert(signup_rate, 0, 0)
cust_df['signup_rate'] = signup_rate.tolist()

cust_cancel_rate = np.array(cust_df[1:]['cust_cancel']) / np.array(cust_df[:-1]['total_cust'])
cust_cancel_rate = np.insert(cust_cancel_rate, 0, 0)
cust_df['cust_cancel_rate'] = cust_cancel_rate.tolist()

cust_df['annual_sub_revenue(million)'] = cust_df['prod_1_sub']*1200/1000000
cust_df['monthly_sub_revenue(million)'] = cust_df['prod_2_sub']*125/1000000
cust_df['annual_sub_rate'] = cust_df['prod_1_sub']/cust_df['total_cust']
cust_df['monthly_sub_rate'] = cust_df['prod_2_sub']/cust_df['total_cust']

cust_df.drop(columns=['cancel_year', 'cancel_month', 'sub_year', 'sub_month'], inplace=True)
cust_df
# Out:
#     year  month  signup  cust_cancel  prod_1_sub  prod_2_sub  total_cust  \
# 0   2017      1    1306           13        2285         630      251616
# 1   2017      2    1183           20        2078        1164      252779
# 2   2017      3    1367           62        2388        1825      254084
# 3   2017      4    1182           75        2109        2427      255191
# 4   2017      5    1299          115        2237        3028      256375
# 5   2017      6     990          119        1805        3471      257246
# 6   2017      7     909          152        1582        3853      258003
# 7   2017      8     721          153        1318        4173      258571
# 8   2017      9     513          146         980        4354      258938
# 9   2017     10     431          192         768        4541      259177
# 10  2017     11     336          160         635        4633      259353
# 11  2017     12     188          169         367        4689      259372
# 12  2018      1    1888          238        5333        5802      261022
# 13  2018      2    1724          221        4793        6754      262525
# 14  2018      3    1912          286        5479        7851      264151
# 15  2018      4    1842          288        5068        8807      265705
# 16  2018      5    1806          375        5162        9844      267136
# 17  2018      6    1571          410        4378       10676      268297
# 18  2018      7    1506          414        4061       11431      269389
# 19  2018      8    1347          443        3569       12104      270293
# 20  2018      9    1036          447        2711       12589      270882
# 21  2018     10     991          497        2337       13024      271376
# 22  2018     11     763          492        1847       13303      271647
# 23  2018     12     534          568        1312       13482      271613
# 24  2019      1    3035          544        9686       15283      274104
# 25  2019      2    2616          587        8619       16783      276133
# 26  2019      3    3001          664        9643       18552      278470
# 27  2019      4    3048          729        9497       20254      280789
# 28  2019      5    3015          801        9457       22074      283003
# 29  2019      6    2679          879        8244       23501      284803
# 30  2019      7    2806          976        8154       25006      286633
# 31  2019      8    2416         1042        7112       26237      288007
# 32  2019      9    2211         1103        5895       27221      289115
# 33  2019     10    2034         1062        5366       28222      290087
# 34  2019     11    1592         1097        4213       28915      290582
# 35  2019     12    1589         1185        3609       29520      290986
# 36  2020      1    3675         1212       13415       32965      293449
# 37  2020      2    3292         1262       12059       35910      295479
# 38  2020      3    3575         1417       13227       39271      297637
# 39  2020      4    3552         1452       13051       42540      299737
# 40  2020      5    3371         1725       12671       45628      301383
# 41  2020      6    3401         1608       11688       48506      303176
# 42  2020      7    3138         1811       11145       51337      304503
# 43  2020      8    2744         1871        9850       53581      305376
# 44  2020      9    2408         1911        8502       55375      305873
# 45  2020     10    2128         1989        7463       56914      306012
# 46  2020     11    1708         2079        5946       57923      305641
# 47  2020     12    1534         2250        5180       58639      304925
# 48  2021      1    3891         2269       15283       68423      306547
# 49  2021      2    3655         2176       13697       77687      308026
# 50  2021      3    4321         2815       15199       88689      309532
# 51  2021      4    4119         2776       14871       98425      310875
# 52  2021      5    3920         3153       14382      107000      311642
# 53  2021      6    3733         3103       13129      113972      312272
# 54  2021      7    3278         3390       12304      119497      312160
# 55  2021      8    2925         3492       10642      123318      311593
# 56  2021      9    2515         3562        9146      125494      310546
# 57  2021     10    2024         3783        7822      126197      308787
# 58  2021     11    1767         3778        6147      125821      306776
# 59  2021     12    1466         3889        5263      124562      304353
#
#     signup_rate  cust_cancel_rate  annual_sub_revenue(million)  \
# 0      0.000000          0.000000                       2.7420
# 1      0.004702          0.000079                       2.4936
# 2      0.005408          0.000245                       2.8656
# 3      0.004652          0.000295                       2.5308
# 4      0.005090          0.000451                       2.6844
# 5      0.003862          0.000464                       2.1660
# 6      0.003534          0.000591                       1.8984
# 7      0.002795          0.000593                       1.5816
# 8      0.001984          0.000565                       1.1760
# 9      0.001664          0.000741                       0.9216
# 10     0.001296          0.000617                       0.7620
# 11     0.000725          0.000652                       0.4404
# 12     0.007279          0.000918                       6.3996
# 13     0.006605          0.000847                       5.7516
# 14     0.007283          0.001089                       6.5748
# 15     0.006973          0.001090                       6.0816
# 16     0.006797          0.001411                       6.1944
# 17     0.005881          0.001535                       5.2536
# 18     0.005613          0.001543                       4.8732
# 19     0.005000          0.001644                       4.2828
# 20     0.003833          0.001654                       3.2532
# 21     0.003658          0.001835                       2.8044
# 22     0.002812          0.001813                       2.2164
# 23     0.001966          0.002091                       1.5744
# 24     0.011174          0.002003                      11.6232
# 25     0.009544          0.002142                      10.3428
# 26     0.010868          0.002405                      11.5716
# 27     0.010946          0.002618                      11.3964
# 28     0.010738          0.002853                      11.3484
# 29     0.009466          0.003106                       9.8928
# 30     0.009852          0.003427                       9.7848
# 31     0.008429          0.003635                       8.5344
# 32     0.007677          0.003830                       7.0740
# 33     0.007035          0.003673                       6.4392
# 34     0.005488          0.003782                       5.0556
# 35     0.005468          0.004078                       4.3308
# 36     0.012629          0.004165                      16.0980
# 37     0.011218          0.004301                      14.4708
# 38     0.012099          0.004796                      15.8724
# 39     0.011934          0.004878                      15.6612
# 40     0.011247          0.005755                      15.2052
# 41     0.011285          0.005335                      14.0256
# 42     0.010350          0.005973                      13.3740
# 43     0.009011          0.006144                      11.8200
# 44     0.007885          0.006258                      10.2024
# 45     0.006957          0.006503                       8.9556
# 46     0.005581          0.006794                       7.1352
# 47     0.005019          0.007362                       6.2160
# 48     0.012761          0.007441                      18.3396
# 49     0.011923          0.007098                      16.4364
# 50     0.014028          0.009139                      18.2388
# 51     0.013307          0.008968                      17.8452
# 52     0.012610          0.010142                      17.2584
# 53     0.011978          0.009957                      15.7548
# 54     0.010497          0.010856                      14.7648
# 55     0.009370          0.011187                      12.7704
# 56     0.008071          0.011432                      10.9752
# 57     0.006518          0.012182                       9.3864
# 58     0.005722          0.012235                       7.3764
# 59     0.004779          0.012677                       6.3156
#
#     monthly_sub_revenue(million)  annual_sub_rate  monthly_sub_rate
# 0                       0.078750         0.009081          0.002504
# 1                       0.145500         0.008221          0.004605
# 2                       0.228125         0.009398          0.007183
# 3                       0.303375         0.008264          0.009511
# 4                       0.378500         0.008725          0.011811
# 5                       0.433875         0.007017          0.013493
# 6                       0.481625         0.006132          0.014934
# 7                       0.521625         0.005097          0.016139
# 8                       0.544250         0.003785          0.016815
# 9                       0.567625         0.002963          0.017521
# 10                      0.579125         0.002448          0.017864
# 11                      0.586125         0.001415          0.018078
# 12                      0.725250         0.020431          0.022228
# 13                      0.844250         0.018257          0.025727
# 14                      0.981375         0.020742          0.029722
# 15                      1.100875         0.019074          0.033146
# 16                      1.230500         0.019323          0.036850
# 17                      1.334500         0.016318          0.039792
# 18                      1.428875         0.015075          0.042433
# 19                      1.513000         0.013204          0.044781
# 20                      1.573625         0.010008          0.046474
# 21                      1.628000         0.008612          0.047992
# 22                      1.662875         0.006799          0.048972
# 23                      1.685250         0.004830          0.049637
# 24                      1.910375         0.035337          0.055756
# 25                      2.097875         0.031213          0.060779
# 26                      2.319000         0.034629          0.066621
# 27                      2.531750         0.033823          0.072132
# 28                      2.759250         0.033417          0.077999
# 29                      2.937625         0.028946          0.082517
# 30                      3.125750         0.028448          0.087240
# 31                      3.279625         0.024694          0.091098
# 32                      3.402625         0.020390          0.094153
# 33                      3.527750         0.018498          0.097288
# 34                      3.614375         0.014498          0.099507
# 35                      3.690000         0.012403          0.101448
# 36                      4.120625         0.045715          0.112336
# 37                      4.488750         0.040812          0.121531
# 38                      4.908875         0.044440          0.131943
# 39                      5.317500         0.043542          0.141924
# 40                      5.703500         0.042043          0.151395
# 41                      6.063250         0.038552          0.159993
# 42                      6.417125         0.036601          0.168593
# 43                      6.697625         0.032255          0.175459
# 44                      6.921875         0.027796          0.181039
# 45                      7.114250         0.024388          0.185986
# 46                      7.240375         0.019454          0.189513
# 47                      7.329875         0.016988          0.192306
# 48                      8.552875         0.049855          0.223206
# 49                      9.710875         0.044467          0.252209
# 50                     11.086125         0.049103          0.286526
# 51                     12.303125         0.047836          0.316606
# 52                     13.375000         0.046149          0.343343
# 53                     14.246500         0.042043          0.364977
# 54                     14.937125         0.039416          0.382807
# 55                     15.414750         0.034154          0.395766
# 56                     15.686750         0.029451          0.404108
# 57                     15.774625         0.025331          0.408686
# 58                     15.727625         0.020037          0.410140
# 59                     15.570250         0.017292          0.409268

# %%
monthly_sub = pd.to_datetime(cust_df['year'].astype(str) + '-' + cust_df['month'].astype(str))
monthly_sub_df = pd.concat([monthly_sub,cust_df['monthly_sub_revenue(million)']], axis=1).rename(columns={0:'month'},errors='raise')
monthly_sub_df.index=monthly_sub_df['month']
monthly_sub_df.drop(columns=['month'], inplace=True)

# %%
monthly_sub_df
# Out:
#             monthly_sub_revenue(million)
# month
# 2017-01-01                      0.078750
# 2017-02-01                      0.145500
# 2017-03-01                      0.228125
# 2017-04-01                      0.303375
# 2017-05-01                      0.378500
# 2017-06-01                      0.433875
# 2017-07-01                      0.481625
# 2017-08-01                      0.521625
# 2017-09-01                      0.544250
# 2017-10-01                      0.567625
# 2017-11-01                      0.579125
# 2017-12-01                      0.586125
# 2018-01-01                      0.725250
# 2018-02-01                      0.844250
# 2018-03-01                      0.981375
# 2018-04-01                      1.100875
# 2018-05-01                      1.230500
# 2018-06-01                      1.334500
# 2018-07-01                      1.428875
# 2018-08-01                      1.513000
# 2018-09-01                      1.573625
# 2018-10-01                      1.628000
# 2018-11-01                      1.662875
# 2018-12-01                      1.685250
# 2019-01-01                      1.910375
# 2019-02-01                      2.097875
# 2019-03-01                      2.319000
# 2019-04-01                      2.531750
# 2019-05-01                      2.759250
# 2019-06-01                      2.937625
# 2019-07-01                      3.125750
# 2019-08-01                      3.279625
# 2019-09-01                      3.402625
# 2019-10-01                      3.527750
# 2019-11-01                      3.614375
# 2019-12-01                      3.690000
# 2020-01-01                      4.120625
# 2020-02-01                      4.488750
# 2020-03-01                      4.908875
# 2020-04-01                      5.317500
# 2020-05-01                      5.703500
# 2020-06-01                      6.063250
# 2020-07-01                      6.417125
# 2020-08-01                      6.697625
# 2020-09-01                      6.921875
# 2020-10-01                      7.114250
# 2020-11-01                      7.240375
# 2020-12-01                      7.329875
# 2021-01-01                      8.552875
# 2021-02-01                      9.710875
# 2021-03-01                     11.086125
# 2021-04-01                     12.303125
# 2021-05-01                     13.375000
# 2021-06-01                     14.246500
# 2021-07-01                     14.937125
# 2021-08-01                     15.414750
# 2021-09-01                     15.686750
# 2021-10-01                     15.774625
# 2021-11-01                     15.727625
# 2021-12-01                     15.570250

# %%
from sklearn.model_selection import TimeSeriesSplit

tss = TimeSeriesSplit(n_splits=2)
train_split, test_split = tss.split(monthly_sub_df)
train_data = monthly_sub_df.iloc[train_split[1], :]
test_data = monthly_sub_df.iloc[test_split[1], :]

# %%
train_data
# Out:
#             monthly_sub_revenue(million)
# month
# 2018-09-01                      1.573625
# 2018-10-01                      1.628000
# 2018-11-01                      1.662875
# 2018-12-01                      1.685250
# 2019-01-01                      1.910375
# 2019-02-01                      2.097875
# 2019-03-01                      2.319000
# 2019-04-01                      2.531750
# 2019-05-01                      2.759250
# 2019-06-01                      2.937625
# 2019-07-01                      3.125750
# 2019-08-01                      3.279625
# 2019-09-01                      3.402625
# 2019-10-01                      3.527750
# 2019-11-01                      3.614375
# 2019-12-01                      3.690000
# 2020-01-01                      4.120625
# 2020-02-01                      4.488750
# 2020-03-01                      4.908875
# 2020-04-01                      5.317500

# %%
axs = plt.subplots(1, 2, figsize=(26, 10))[1]
_ = train_data.plot(ax=axs[0])
_ = pd.plotting.autocorrelation_plot(train_data, ax=axs[1])

# %%
#The trained plot shows a trend of going up every year, and correlation barely goes near the line 0

#The data is therefore not stationary

# %%
from statsmodels.tsa.stattools import adfuller

result = adfuller(train_data)
print('ADF Test Statistic: %.4f' % result[0])
print('5%% Critical Value: %.4f' % result[4]['5%'])
print('p-value: %.4f' % result[1])
# Out:
# ADF Test Statistic: -1.2359
# 5% Critical Value: -3.1894
# p-value: 0.6580

# %%
#The abs(ADF) < abs(Critical Value) and p-value > 0.05 also show that the data is non-stationary

# %%
axs = plt.subplots(1, 2, figsize=(26, 10))[1]
_ = train_data.diff().dropna().plot(ax=axs[0])
_ = pd.plotting.autocorrelation_plot(train_data.diff().dropna(), ax=axs[1])

# %%
result = adfuller(train_data.diff().dropna())
print('ADF Test Statistic: %.4f' % result[0])
print('5%% Critical Value: %.4f' % result[4]['5%'])
print('p-value: %.4f' % result[1])
# Out:
# ADF Test Statistic: -1.3064
# 5% Critical Value: -3.0849
# p-value: 0.6262

# %%
#The difference of revenue between adjacent months is stationary

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

axs = plt.subplots(1,2,figsize=(26, 10))[1]
plot_acf(train_data, ax=axs[0]);
plot_acf(train_data.diff().dropna(), ax=axs[1]);

# %%
plot_pacf(train_data.diff().dropna(), lags=8);

# %%
from statsmodels.tsa.arima.model import ARIMA
from pprint import pprint

arima_model = ARIMA(train_data, order=(1, 1, 0))
model = arima_model.fit()
pprint(model.summary())
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                     SARIMAX Results
# ========================================================================================
# Dep. Variable:     monthly_sub_revenue(million)   No. Observations:                   20
# Model:                           ARIMA(1, 1, 0)   Log Likelihood                  15.956
# Date:                          Sat, 15 Apr 2023   AIC                            -27.912
# Time:                                  15:30:26   BIC                            -26.024
# Sample:                              09-01-2018   HQIC                           -27.593
#                                    - 04-01-2020
# Covariance Type:                            opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9220      0.146      6.328      0.000       0.636       1.208
# sigma2         0.0099      0.002      6.014      0.000       0.007       0.013
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.43   Jarque-Bera (JB):                43.82
# Prob(Q):                              0.23   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.06   Skew:                             2.49
# Prob(H) (two-sided):                  0.20   Kurtosis:                         8.53
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """
# C:\Users\OEM\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\OEM\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\OEM\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
prediction = model.predict(dynamic=False)

# %%
Mape = np.mean(np.abs(np.array(prediction) - np.array(train_data).flatten())/np.abs(np.array(train_data).flatten()))
1-Mape
# Out:
# 0.9321341110240876

# %%
# According to MAPE score, our model has 93% accuracy on predicting the annual subs revenue, which is a strong enough result to use to predict future monthly subscription revenue
